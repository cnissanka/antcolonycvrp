# %%
## build the csv 
import pandas as pd 
data = [] 
def add_row(row):
    data.append(row) 

add_row(['Matara', '0', '5.95453', '80.5492']); 
add_row(['Katunayaka','625.8', '7.17229', '79.8853']);
add_row(['Divulapiyiya','765.12','7.22952','80.0151']);
add_row(['Mirigama', '1103.76', '7.24274', '80.127']); 
add_row(['Gampaha', '1061.26', '7.08731','80.0144']); 
add_row(['Kalaniya', '1373.88', '6.95179', '79.9133']); 
add_row(['Homagama', '1439.08', '6.84328', '80.0032']); 
add_row(['Piliyandala', '1878.58', '6.8018', '79.9227']); 
add_row(['Panadura', '1256.14', '6.72023', '79.9305']); 
add_row(['Horana', '857.56', '6.72297', '80.0647'])
add_row(['Kaluthara', '675.07', '6.5854', '79.9607']) 
add_row(['Mathugama', '867.67', '6.52195', '80.1137']) 
add_row(['Awissawella', '790.3', '6.95433', '80.2046']) 
add_row(['Ambalangoda', '1250.66', '6.24416', '80.0591'])
add_row(['Elpitiya', '147.78', '6.28804', '80.1596']) 
add_row(['Neluwa','842.2','6.37318','80.3575']) 
add_row(['Baddegama','724.72','6.1688','80.1794'])
add_row(['Deniyaya','1335.38','6.34249','80.5597']) 
add_row(['Urubokka','731.02','6.30653','80.6306'])
add_row(['Akuressa','1019.83','6.10014','80.476'])
add_row(['Weligama','1066.09','5.9774','80.4288'])
add_row(['Kaburupitiya','1256.83','6.07792','80.5633'])
add_row(['Walasmulla','1177','6.15089','80.6937'])
add_row(['Beliatta','817.75','6.04816','80.7339'])
add_row(['Dikwalle','670.25','5.97168','80.6951'])
add_row(['Agunukolapalassa','428.34','6.16557','80.9031'])
add_row(['Ambalanthota','1193.32','6.1226','81.0238'])
add_row(['Thissamaharama','1610.04','6.27916','81.2877'])
add_row(['Alawwa','704.56','7.29543','80.2366'])
add_row(['Kegalle','960.88','7.25133','80.3464'])
add_row(['Mawanella','1080.14','7.24813','80.4466'])
add_row(['Kandy','943.47','7.29057','80.6337'])
add_row(['Digana','1111.52','7.29419','80.7381'])
add_row(['Gampola','939.25','7.17326','80.5605'])
add_row(['Ruwanwella','530.11','7.04587','80.2537'])
add_row(['Hatton','2671.52','6.90035','80.5966'])
add_row(['Kuruwita','613.73','6.82184','80.3615'])
add_row(['Ratnapura','1111.89','6.70558','80.3847'])
add_row(['Balngoda','1391.83','6.66688','80.7048'])
add_row(['Godakawela','1138.58','6.50491','80.6521'])
add_row(['Embilipitiya','1436.76','6.31623','80.8433'])
add_row(['Dankotuwa','834.69','7.29746','79.8822'])
add_row(['Ahangama','1448.5','5.97398','80.3622'])
add_row(['Kiridiwela','1515.95','7.04118','80.1289'])
add_row(['Wattala','333.31','7.00251','79.9099'])
add_row(['Maharagama','1121.82','6.85222','79.9249'])
add_row(['Mahiyanganaya','2270.21','7.33161','81.0037'])
add_row(['Ampara','1805.25','7.23176','81.6473'])
add_row(['Meegoda','788.14','6.8216','80.0475'])
add_row(['Monaragala','1986.85','6.89065','81.3454'])
add_row(['Biyagama','750.89','6.94622','79.9892'])
add_row(['Bandarawela','1818.84','6.82588','80.9982'])
add_row(['Wellawaya','1430.38','6.73774','81.1031'])
add_row(['Kaduwela','780.3','6.93083','79.9842'])
add_row(['Walapane','1495.6','7.10217','80.8627'])
add_row(['Peradeniya','1345.61','7.26987','80.5938'])
add_row(['Welimada','1199.4','6.90191','80.9079'])
add_row(['Badulla','1369.48','6.9934','81.055'])
add_row(['Passara','1134.86','6.93491','81.1527'])
add_row(['Mawathagama','512.4','7.43216','80.4438'])
add_row(['Yatiyanthota','693.15','7.02888','80.2955'])
add_row(['Pannala','723.08','7.32954','80.0228'])
add_row(['Negambo','620.15','7.2008','79.8737'])
add_row(['Borella','1075.28','6.91218','79.8829'])
add_row(['Maradana','548.69','6.927','79.864'])
add_row(['Anuradhapura','703.85','8.31135','80.4037'])
add_row(['Eppawala','622.72','8.1441','80.4119'])
add_row(['Higurakgoda','847.19','8.04159','80.9532'])
add_row(['Kurunegala','408.16','7.47298','80.3547'])
add_row(['Matale','1019.3','7.46747','80.6234'])
add_row(['Polonnaruwa','964.61','7.94034','81.0188'])
add_row(['Thabuttegama','533.19','8.154','80.3046'])
add_row(['Trincomale','837.91','8.58737','81.2152'])
add_row(['Vavuniya','550.76','8.7542','80.4982'])
add_row(['Chilaw','582.31','7.56199','79.8017'])
add_row(['Dambulla','828.74','7.87422','80.6511'])
add_row(['Galenbindunawewa','472.63','8.29214','80.7173'])
add_row(['Ambanpola','449.85','7.91812','80.2405'])
add_row(['Jaffna','1461.2','9.6615','80.0255'])
add_row(['Wariyapola','49.37','7.62391','80.2433'])
add_row(['Puttalama','457.33','8.09828','80.0088'])
add_row(['Padaviya','244.14','8.8341','80.7607'])


df = pd.DataFrame(data)
df.columns  = ['name','demand','long','lat'] 
df.to_csv('points.csv')

# %%
# create the cost matrix using distance api - google 
import requests 

googleKey = "AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM" 
def constructUrl(origin, destination, apiKey=googleKey): 
    base = "https://maps.googleapis.com/maps/api/distancematrix/json?units=metric"; 
    base += "&origins=" + origin[0] + "," + origin[1] 
    base += "&destinations=" + destination[0] + "," + destination[1] 
    base += "&key=" + apiKey
    return base

def getResult(url):
    resp = requests.get(url)
    return resp.json()

def getDistanceFromJson(jsonObj):
    return jsonObj['rows'][0]['elements'][0]['distance']['value'] 

def getDistance(originLong, originLat, destinationLong, destinationLat):
    googleUrl = constructUrl([originLong, originLat], [destinationLong, destinationLat], googleKey)
    print(googleUrl)
    jsonObj = getResult(googleUrl) 
    distance = (getDistanceFromJson(jsonObj))/1000; 
    return distance

# %%
# create clusters 
import numpy as np
from scipy.spatial.distance import pdist

# %%
df = pd.DataFrame(data)
from scipy.spatial import distance_matrix
df = df[[2,3]]

x_series = df[[2]].to_numpy().reshape(1,82)[0]
y_series = df[[3]].to_numpy().reshape(1,82)[0] 

x = pd.to_numeric(x_series)
y = pd.to_numeric(y_series)

df = pd.DataFrame(np.array([x,y]).reshape(82,2))

#distance matrix to all the points
distanceMatrix = pd.DataFrame(distance_matrix(df.values, df.values))

# %%
distanceMatrix
# Out:
#             0           1           2           3           4           5   \
# 0     0.000000    1.276935    1.154041    0.962881    0.887798    0.906057
# 1     1.276935    0.000000    0.323845    0.586182    0.727693    0.966659
# 2     1.154041    0.323845    0.000000    0.286440    0.432558    0.660815
# 3     0.962881    0.586182    0.286440    0.000000    0.146135    0.380550
# 4     0.887798    0.727693    0.432558    0.146135    0.000000    0.242050
# ..         ...         ...         ...         ...         ...         ...
# 77  105.075485  104.116489  104.422308  104.701203  104.844099  105.081362
# 78  104.175525  103.225523  103.532463  103.810646  103.953209  104.190966
# 79  104.539156  103.581498  103.887489  104.166278  104.309125  104.546464
# 80  104.047494  103.093824  103.400314  103.678789  103.821489  104.059049
# 81  104.399660  103.449089  103.755958  104.034188  104.176773  104.414499
#
#             6           7           8           9   ...          72  \
# 0     1.364194    0.865913    0.857018    1.128455  ...  103.686434
# 1     1.035805    1.281608    1.391250    1.468824  ...  102.731542
# 2     0.720017    0.986723    1.102228    1.155390  ...  103.037883
# 3     0.568590    0.701432    0.816020    0.883418  ...  103.316453
# 4     0.532975    0.556005    0.669955    0.747706  ...  103.459197
# ..         ...         ...         ...         ...  ...         ...
# 77  105.015900  105.397333  105.503704  105.576419  ...    1.475878
# 78  104.130361  104.505826  104.611536  104.687084  ...    0.771567
# 79  104.481740  104.862270  104.968542  105.041685  ...    0.916263
# 80  103.996484  104.374363  104.480342  104.554745  ...    0.391064
# 81  104.353583  104.729430  104.835183  104.910552  ...    0.888136
#
#             73          74          75          76          77          78  \
# 0   104.045419  104.821384  104.548797  104.799711  105.075485  104.175525
# 1   103.093616  103.869594  103.595430  103.840711  104.116489  103.225523
# 2   103.400337  104.176313  103.901956  104.146531  104.422308  103.532463
# 3   103.678663  104.454641  104.180408  104.425425  104.701203  103.810646
# 4   103.821294  104.597272  104.323098  104.568321  104.844099  103.953209
# ..         ...         ...         ...         ...         ...         ...
# 77    1.354501    0.923210    0.869560    0.275779    0.000000    1.421746
# 78    0.255124    0.680888    0.553693    1.265462    1.421746    0.000000
# 79    0.868766    0.775378    0.527344    0.308239    0.560637    1.003452
# 80    0.227619    0.808247    0.502841    0.995190    1.216700    0.465174
# 81    0.385248    0.446706    0.372153    1.108209    1.234628    0.234313
#
#             79          80          81
# 0   104.539156  104.047494  104.399660
# 1   103.581498  103.093824  103.449089
# 2   103.887489  103.400314  103.755958
# 3   104.166278  103.678789  104.034188
# 4   104.309125  103.821489  104.176773
# ..         ...         ...         ...
# 77    0.560637    1.216700    1.234628
# 78    1.003452    0.465174    0.234313
# 79    0.000000    0.691806    0.878965
# 80    0.691806    0.000000    0.517669
# 81    0.878965    0.517669    0.000000
#
# [82 rows x 82 columns]

# %%
from collections import OrderedDict

class Node(object):
    def __init__(self, distance, demand):
        self.distance = distance; 
        self.demand = demand 
        self.nonClustered = True; 
    
    def getDemand(self):
        return self.demand
    
    def getDistance(self):
        return self.distance 
    
    def __str__(self):
        return str(self.demand) + " " + str(self.distance)   
    
def getDistancesFromNodeToAllNodes(node, distanceMatrix, isNonClusterMap): 
    distances = distanceMatrix.iloc[:, node] 
    result = {} 
    for index, distance in enumerate(distances):
        if (distances[index] != 0 and isNonClusterMap[index]):
            result[index] = Node(distance, data[index][1]) 
    
    items = OrderedDict(sorted(result.items(), key=lambda x: x[1].distance, reverse=False))
    
    return items

# %%
def markAsNonClustered(data):
    return createNodeMap(data, True) 

def createNodeMap(data, flag):
    nodeMap = {} 
    for index, d in enumerate(data): 
        nodeMap[index] = flag 
    return nodeMap 

def createDemandMap(data):
    demandMap = {} 
    for index, d in enumerate(data):
        demandMap[index] = float(d[1])
    return demandMap 

def areThereNonClusterNodes(clusterMap, size=82):
    index = 0; 
    while (index < size):
        if clusterMap[index]:
            return True
        index += 1 
    return False

# %%
def createClusterFor(index, isClusterMap, demandMap, capacity):
    clusterPoints = [] 
    iterationCount = 1
    while (areThereNonClusterNodes(isClusterMap)):       
        distancesFromIndex = getDistancesFromNodeToAllNodes(index, distanceMatrix, isClusterMap) 
        newCluster = [index]
        isClusterMap[index] = False 
        totalDemand = demandMap[index]
        distanceKeys = list(distancesFromIndex.keys()); 
        distanceIndex = 0; 
        while (totalDemand <= capacity and distanceIndex < len(distanceKeys)):
            distanceKey = distanceKeys[distanceIndex]
            totalDemand += demandMap[distanceKey]
            isClusterMap[distanceKey] = False; 
            newCluster.append(distanceKey) 
            distanceIndex += 1; 
        clusterPoints.append(newCluster)
    
        if (distanceIndex >= len(distanceKeys)):
            break;
        else:
            index = distanceIndex;
        print("created cluster {}".format(iterationCount)) 
        iterationCount += 1 
    return clusterPoints

CAPACITY = 3500
numberOfNodes = len(data)
isClusteredMap = markAsNonClustered(data)
demandMap = createDemandMap(data) 
clusters = []; 

for k in range(numberOfNodes):
    cluster = createClusterFor(k, isClusteredMap, demandMap, CAPACITY);
    isClusteredMap = markAsNonClustered(data);  
    clusters.append(cluster)

clusters
# Out:
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 27
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 27
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# created cluster 26
# created cluster 1
# created cluster 2
# created cluster 3
# created cluster 4
# created cluster 5
# created cluster 6
# created cluster 7
# created cluster 8
# created cluster 9
# created cluster 10
# created cluster 11
# created cluster 12
# created cluster 13
# created cluster 14
# created cluster 15
# created cluster 16
# created cluster 17
# created cluster 18
# created cluster 19
# created cluster 20
# created cluster 21
# created cluster 22
# created cluster 23
# created cluster 24
# created cluster 25
# [[[0, 21, 20, 26],
#   [3, 24, 18, 25, 4],
#   [4, 19, 5, 22],
#   [3, 28, 17, 2],
#   [3, 31, 27],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 30, 29, 34, 6],
#   [4, 13, 9, 11],
#   [3, 12, 10, 37],
#   [3, 32, 35],
#   [2, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[1, 15, 14, 16, 23, 27],
#   [5, 19, 4, 18],
#   [3, 24, 25, 26, 22],
#   [4, 28, 17, 2],
#   [3, 31, 30, 6],
#   [3, 29, 7],
#   [2, 34, 20, 37, 8],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 28, 27, 30],
#   [3, 6, 16, 1],
#   [3, 15, 29, 14, 23],
#   [4, 7, 8],
#   [2, 34, 20, 37, 21],
#   [4, 13, 9, 11],
#   [3, 0, 12, 10, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[4, 18, 3, 24],
#   [3, 25, 26, 22],
#   [3, 28, 17, 2],
#   [3, 19, 31, 5],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 6],
#   [3, 20, 9, 13],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[5, 19, 4, 18],
#   [3, 24, 25, 26, 22],
#   [4, 28, 17, 2],
#   [3, 31, 27],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 30, 29, 34, 6],
#   [4, 20, 13, 9],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[6, 19, 5],
#   [2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 28, 7],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 8, 9, 13],
#   [3, 29, 20, 21],
#   [3, 34, 0, 11, 12, 10],
#   [5, 37, 32],
#   [2, 35, 33],
#   [2, 38, 40],
#   [2, 36, 39, 72, 63],
#   [4, 44, 43, 45],
#   [3, 46, 42],
#   [2, 47, 80, 73],
#   [3, 71, 41, 78],
#   [3, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[7, 8, 13],
#   [2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 28, 27, 30],
#   [3, 6, 16, 1],
#   [3, 15, 29, 14, 23],
#   [4, 20, 9, 21],
#   [3, 34, 0, 11, 12, 10],
#   [5, 37, 32],
#   [2, 35, 33],
#   [2, 38, 40],
#   [2, 36, 39, 72, 63],
#   [4, 44, 43, 45],
#   [3, 46, 42],
#   [2, 47, 80, 73],
#   [3, 71, 41, 78],
#   [3, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[8, 13, 7],
#   [2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 28, 27, 30],
#   [3, 6, 16, 1],
#   [3, 15, 29, 14, 23],
#   [4, 20, 9, 21],
#   [3, 34, 0, 11, 12, 10],
#   [5, 37, 32],
#   [2, 35, 33],
#   [2, 38, 40],
#   [2, 36, 39, 72, 63],
#   [4, 44, 43, 45],
#   [3, 46, 42],
#   [2, 47, 80, 73],
#   [3, 71, 41, 78],
#   [3, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[9, 11, 13, 7],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 8, 12, 10],
#   [3, 29, 20, 21],
#   [3, 34, 0, 37, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[10, 12, 11, 13],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 9, 21, 0, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[11, 9, 10, 12, 13],
#   [4, 18, 3, 24],
#   [3, 25, 26, 22],
#   [3, 28, 17, 2],
#   [3, 19, 31, 5],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 6],
#   [3, 20, 21, 0, 37],
#   [4, 32, 35],
#   [2, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[12, 10, 13, 11],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 9, 21, 0, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[13, 8, 12, 7],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 9, 11, 10],
#   [3, 29, 20, 21],
#   [3, 34, 0, 37, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[14, 23, 15, 1, 16, 27],
#   [5, 19, 4, 18],
#   [3, 24, 25, 26, 22],
#   [4, 28, 17, 2],
#   [3, 31, 30, 6],
#   [3, 29, 7],
#   [2, 34, 20, 37, 8],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[15, 1, 14, 23, 16, 27],
#   [5, 19, 4, 18],
#   [3, 24, 25, 26, 22],
#   [4, 28, 17, 2],
#   [3, 31, 30, 6],
#   [3, 29, 7],
#   [2, 34, 20, 37, 8],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[16, 23, 14, 1, 15, 27],
#   [5, 19, 4, 18],
#   [3, 24, 25, 26, 22],
#   [4, 28, 17, 2],
#   [3, 31, 30, 6],
#   [3, 29, 7],
#   [2, 34, 20, 37, 8],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[17, 22, 2, 25],
#   [3, 24, 18, 4],
#   [3, 26, 28, 19],
#   [3, 31, 5, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
# ...
#   [6, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[50, 57, 60, 51],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 56, 67],
#   [3, 76, 74, 65, 52],
#   [4, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[51, 56, 75],
#   [2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 28, 27, 30],
#   [3, 6, 16, 1],
#   [3, 15, 29, 14, 23],
#   [4, 7, 8],
#   [2, 34, 20, 37, 21],
#   [4, 13, 9, 11],
#   [3, 0, 12, 10, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 66, 67],
#   [6, 50, 57],
#   [2, 76, 60, 74, 65, 52],
#   [5, 68, 70, 53],
#   [3, 77, 69, 54],
#   [3, 64]],
#  [[52, 60, 53, 57],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 76, 74, 65, 68, 70],
#   [5, 77, 69, 54],
#   [3, 64]],
#  [[53, 52, 60, 69],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 74],
#   [3, 65, 68, 70, 77],
#   [4, 54, 64]],
#  [[54, 69, 64, 53],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 77]],
#  [[55, 48, 59, 49],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 61, 81, 58],
#   [4, 79, 75, 66, 51],
#   [4, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[56, 51, 75],
#   [2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 28, 27, 30],
#   [3, 6, 16, 1],
#   [3, 15, 29, 14, 23],
#   [4, 7, 8],
#   [2, 34, 20, 37, 21],
#   [4, 13, 9, 11],
#   [3, 0, 12, 10, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 66, 67],
#   [6, 50, 57],
#   [2, 76, 60, 74, 65, 52],
#   [5, 68, 70, 53],
#   [3, 77, 69, 54],
#   [3, 64]],
#  [[57, 60, 68, 50, 52],
#   [4, 18, 3, 24],
#   [3, 25, 26, 22],
#   [3, 28, 17, 2],
#   [3, 19, 31, 5],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 6],
#   [3, 20, 9, 13],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 76, 74],
#   [4, 65, 70, 53],
#   [3, 77, 69, 54],
#   [3, 64]],
#  [[58, 49, 75],
#   [2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 28, 27, 30],
#   [3, 6, 16, 1],
#   [3, 15, 29, 14, 23],
#   [4, 7, 8],
#   [2, 34, 20, 37, 21],
#   [4, 13, 9, 11],
#   [3, 0, 12, 10, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 59, 81, 79, 66, 51],
#   [6, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[59, 55, 51],
#   [2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 28, 27, 30],
#   [3, 6, 16, 1],
#   [3, 15, 29, 14, 23],
#   [4, 7, 8],
#   [2, 34, 20, 37, 21],
#   [4, 13, 9, 11],
#   [3, 0, 12, 10, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 61],
#   [3, 49, 81, 58],
#   [3, 79, 75, 66, 56],
#   [4, 67, 50, 57],
#   [3, 76, 60, 74, 65],
#   [4, 52, 68, 70],
#   [3, 53, 77, 69, 54],
#   [4, 64]],
#  [[60, 52, 57, 68],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 76, 74, 65, 70],
#   [4, 53, 77, 69, 54],
#   [4, 64]],
#  [[61, 67, 41, 79, 76, 62],
#   [5, 19, 4, 18],
#   [3, 24, 25, 26, 22],
#   [4, 28, 17, 2],
#   [3, 31, 27],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 30, 29, 34, 6],
#   [4, 20, 13, 9],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 78],
#   [4, 48, 55, 49],
#   [3, 59, 81, 58, 75],
#   [4, 66, 51],
#   [2, 56, 50, 57],
#   [3, 60, 74, 65, 52],
#   [4, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[62, 71, 47, 55],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 80, 73, 41],
#   [4, 78, 48, 61],
#   [3, 49, 59],
#   [2, 81, 58, 79, 75, 66],
#   [5, 51, 56],
#   [2, 67, 50, 57],
#   [3, 76, 60, 74, 65],
#   [4, 52, 68, 70],
#   [3, 53, 77, 69, 54],
#   [4, 64]],
#  [[63, 72, 44, 43],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 45],
#   [3, 46, 42],
#   [2, 47, 80, 73],
#   [3, 71, 41, 78],
#   [3, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[64, 54, 69, 53],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 77]],
#  [[65, 66, 74, 81, 78],
#   [4, 18, 3, 24],
#   [3, 25, 26, 22],
#   [3, 28, 17, 2],
#   [3, 19, 31, 5],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 6],
#   [3, 20, 9, 13],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 62],
#   [5, 48, 55],
#   [2, 61, 49, 59],
#   [3, 58, 79, 75, 51],
#   [4, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 52, 68, 70],
#   [3, 53, 77, 69, 54],
#   [4, 64]],
#  [[66, 81, 65, 78, 74],
#   [4, 18, 3, 24],
#   [3, 25, 26, 22],
#   [3, 28, 17, 2],
#   [3, 19, 31, 5],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 6],
#   [3, 20, 9, 13],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 62],
#   [5, 48, 55],
#   [2, 61, 49, 59],
#   [3, 58, 79, 75, 51],
#   [4, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 52, 68, 70],
#   [3, 53, 77, 69, 54],
#   [4, 64]],
#  [[67, 61, 76, 70, 79, 77],
#   [5, 19, 4, 18],
#   [3, 24, 25, 26, 22],
#   [4, 28, 17, 2],
#   [3, 31, 27],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 30, 29, 34, 6],
#   [4, 20, 13, 9],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 49, 59],
#   [2, 81, 58, 75, 66],
#   [4, 51, 56],
#   [2, 50, 57, 60],
#   [3, 74, 65, 52],
#   [3, 68, 53, 69, 54],
#   [4, 64]],
#  [[68, 57, 60, 52],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 76, 74, 65, 70],
#   [4, 53, 77, 69, 54],
#   [4, 64]],
#  [[69, 54, 53, 52],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 68, 70],
#   [4, 77, 64]],
#  [[70, 77, 76, 68, 57],
#   [4, 18, 3, 24],
#   [3, 25, 26, 22],
#   [3, 28, 17, 2],
#   [3, 19, 31, 5],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 6],
#   [3, 20, 9, 13],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 60, 74, 65, 52],
#   [4, 53, 69, 54],
#   [3, 64]],
#  [[71, 47, 62, 41],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 80, 73, 78],
#   [4, 48, 55, 61],
#   [3, 49, 59],
#   [2, 81, 58, 79, 75, 66],
#   [5, 51, 56],
#   [2, 67, 50, 57],
#   [3, 76, 60, 74, 65],
#   [4, 52, 68, 70],
#   [3, 53, 77, 69, 54],
#   [4, 64]],
#  [[72, 63, 44, 43],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 45],
#   [3, 46, 42],
#   [2, 47, 80, 73],
#   [3, 71, 41, 78],
#   [3, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[73, 80, 78, 48, 46],
#   [4, 18, 3, 24],
#   [3, 25, 26, 22],
#   [3, 28, 17, 2],
#   [3, 19, 31, 5],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 6],
#   [3, 20, 9, 13],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 42],
#   [2, 47, 71, 41],
#   [3, 62, 55, 61],
#   [3, 49, 59],
#   [2, 81, 58, 79, 75, 66],
#   [5, 51, 56],
#   [2, 67, 50, 57],
#   [3, 76, 60, 74, 65],
#   [4, 52, 68, 70],
#   [3, 53, 77, 69, 54],
#   [4, 64]],
#  [[74, 53, 56, 75, 52],
#   [4, 18, 3, 24],
#   [3, 25, 26, 22],
#   [3, 28, 17, 2],
#   [3, 19, 31, 5],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 6],
#   [3, 20, 9, 13],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 66, 51],
#   [6, 67, 50, 57],
#   [3, 76, 60, 65, 68, 70],
#   [5, 77, 69, 54],
#   [3, 64]],
#  [[75, 56, 51],
#   [2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 28, 27, 30],
#   [3, 6, 16, 1],
#   [3, 15, 29, 14, 23],
#   [4, 7, 8],
#   [2, 34, 20, 37, 21],
#   [4, 13, 9, 11],
#   [3, 0, 12, 10, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 66, 67],
#   [6, 50, 57],
#   [2, 76, 60, 74, 65, 52],
#   [5, 68, 70, 53],
#   [3, 77, 69, 54],
#   [3, 64]],
#  [[76, 70, 77, 79, 68, 67, 57],
#   [6, 19, 5],
#   [2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 28, 7],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 8, 9, 13],
#   [3, 29, 20, 21],
#   [3, 34, 0, 11, 12, 10],
#   [5, 37, 32],
#   [2, 35, 33],
#   [2, 38, 40],
#   [2, 36, 39, 72, 63],
#   [4, 44, 43, 45],
#   [3, 46, 42],
#   [2, 47, 80, 73],
#   [3, 71, 41, 78],
#   [3, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 75, 66],
#   [5, 51, 56],
#   [2, 50, 60, 74, 65, 52],
#   [5, 53, 69, 54],
#   [3, 64]],
#  [[77, 70, 76, 68, 57],
#   [4, 18, 3, 24],
#   [3, 25, 26, 22],
#   [3, 28, 17, 2],
#   [3, 19, 31, 5],
#   [3, 27, 30],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 6],
#   [3, 20, 9, 13],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 60, 74, 65, 52],
#   [4, 53, 69, 54],
#   [3, 64]],
#  [[78, 81, 73, 49],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 71, 41, 62, 48],
#   [5, 55, 61, 59],
#   [3, 58, 79, 75, 66],
#   [4, 51, 56],
#   [2, 67, 50, 57],
#   [3, 76, 60, 74, 65],
#   [4, 52, 68, 70],
#   [3, 53, 77, 69, 54],
#   [4, 64]],
#  [[79, 50, 76, 57, 62, 61],
#   [5, 19, 4, 18],
#   [3, 24, 25, 26, 22],
#   [4, 28, 17, 2],
#   [3, 31, 27],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 30, 29, 34, 6],
#   [4, 20, 13, 9],
#   [3, 21, 0, 11, 12],
#   [4, 10, 37, 32],
#   [3, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 78],
#   [5, 48, 55],
#   [2, 49, 59, 81],
#   [3, 58, 75, 66],
#   [3, 51, 56],
#   [2, 67, 60, 74, 65],
#   [4, 52, 68, 70],
#   [3, 53, 77, 69, 54],
#   [4, 64]],
#  [[80, 42, 46],
#   [2, 17, 31, 22],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 28, 27, 30],
#   [3, 6, 16, 1],
#   [3, 15, 29, 14, 23],
#   [4, 7, 8],
#   [2, 34, 20, 37, 21],
#   [4, 13, 9, 11],
#   [3, 0, 12, 10, 32],
#   [4, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 47],
#   [2, 73, 71, 41, 78],
#   [4, 62, 48, 55],
#   [3, 61, 49],
#   [2, 59, 81, 58, 79, 75],
#   [5, 66, 51],
#   [2, 56, 67, 50],
#   [3, 57, 76, 60],
#   [3, 74, 65, 52],
#   [3, 68, 70, 53, 77],
#   [4, 69, 54],
#   [2, 64]],
#  [[81, 78, 66, 49],
#   [3, 24, 18, 25, 4],
#   [4, 26, 19, 5],
#   [3, 22, 28, 17],
#   [3, 2, 31, 27],
#   [3, 30, 6],
#   [2, 16, 1, 14, 23, 15],
#   [5, 7, 8],
#   [2, 29, 34, 20, 37],
#   [4, 13, 9, 21],
#   [3, 0, 11, 12, 10, 32],
#   [5, 35],
#   [1, 33, 38, 40],
#   [3, 36, 39, 72],
#   [3, 63, 44, 43],
#   [3, 45, 46],
#   [2, 42, 47],
#   [2, 80, 73, 71, 41, 62],
#   [5, 48, 55],
#   [2, 61, 59, 58, 79, 75],
#   [5, 51, 56],
#   [2, 67, 50, 57],
#   [3, 76, 60, 74, 65],
#   [4, 52, 68, 70],
#   [3, 53, 77, 69, 54],
#   [4, 64]]]

# %%
len(clusters)
# Out:
# 82

# %%
clusters[1]
# Out:
# [[1, 15, 14, 16, 23, 27],
#  [5, 19, 4, 18],
#  [3, 24, 25, 26, 22],
#  [4, 28, 17, 2],
#  [3, 31, 30, 6],
#  [3, 29, 7],
#  [2, 34, 20, 37, 8],
#  [4, 13, 9, 21],
#  [3, 0, 11, 12, 10, 32],
#  [5, 35],
#  [1, 33, 38, 40],
#  [3, 36, 39, 72],
#  [3, 63, 44, 43],
#  [3, 45, 46],
#  [2, 42, 47],
#  [2, 80, 73, 71, 41, 78],
#  [5, 62, 48, 55],
#  [3, 61, 49],
#  [2, 59, 81, 58, 79, 75],
#  [5, 66, 51],
#  [2, 56, 67, 50],
#  [3, 57, 76, 60],
#  [3, 74, 65, 52],
#  [3, 68, 70, 53, 77],
#  [4, 69, 54],
#  [2, 64]]

# %%
clusters[3]
# Out:
# [[3, 24, 18, 25, 4],
#  [4, 26, 19, 5],
#  [3, 22, 28, 17],
#  [3, 2, 31, 27],
#  [3, 30, 6],
#  [2, 16, 1, 14, 23, 15],
#  [5, 7, 8],
#  [2, 29, 34, 20, 37],
#  [4, 13, 9, 21],
#  [3, 0, 11, 12, 10, 32],
#  [5, 35],
#  [1, 33, 38, 40],
#  [3, 36, 39, 72],
#  [3, 63, 44, 43],
#  [3, 45, 46],
#  [2, 42, 47],
#  [2, 80, 73, 71, 41, 78],
#  [5, 62, 48, 55],
#  [3, 61, 49],
#  [2, 59, 81, 58, 79, 75],
#  [5, 66, 51],
#  [2, 56, 67, 50],
#  [3, 57, 76, 60],
#  [3, 74, 65, 52],
#  [3, 68, 70, 53, 77],
#  [4, 69, 54],
#  [2, 64]]

# %%
# find best cluster based on the convex hull of ith cluster / number of nodes in that cluster and take the sum
from scipy.spatial import ConvexHull
def createDataMap(data):
    dataMap = {} 
    for index, d in enumerate(data): 
        longitude, latitude = float(d[2]), float(d[3])
        dataMap[index] = [longitude, latitude] 
    return dataMap

def getPointCoordinates(index,data):
    longitude = float(data[index][2])
    latitude = float(data[index][3])
    return [longitude, latitude] 

def getClusterConvexHullArea(points):
    if (len(points) > 2):
        return ConvexHull(points).area
    return 0

def getPointsFromCluster(dataMap, cluster):
    points = [] 
    if not (0 in cluster):
        cluster.insert(0,0)
    for index in cluster:
        p = dataMap[index] 
        points.append(p) 
    return points 
        

def findParameter(dataMap, clusters):
    param = 0 
    for cluster in clusters:
        area = getClusterConvexHullArea(getPointsFromCluster(dataMap, cluster)) 
        numberOfNodes = len(cluster)
        param += (area/numberOfNodes) 
    return param 

dataMap = createDataMap(data)
top3clusters = [20, 20, 20] 
for i in range(len(clusters)):
    param = findParameter(dataMap, clusters[i]) 

    if (top3clusters[0] > param):
        top3clusters[0] = i 
    elif (top3clusters[1] > param): 
        top3clusters[1] = i 
    elif (top3clusters[2] > param): 
        top3clusters[2] = i

# %%
top3clusters
# Out:
# [81, 20, 20]

# %%
#ant colony optimizer 

import pants
import math
import random

memo = {} 

def euclidean(a, b):
    return math.sqrt(pow(a[1] - b[1], 2) + pow(a[0] - b[0], 2))

def getIndexMap(data):
    p = {} 
    for index, d in enumerate(data): 
        longitude, latitude = float(d[2]), float(d[3])
        p[(longitude, latitude)] = index 
    return p 

def getPoints(dataMap, arr):
    l = [] 
    for i in arr:
        l.append((dataMap[i][0], dataMap[i][1]))  
    return l 


def getOptimalRoute(indexMap, dataMap, cluster):
    nodes = getPoints(dataMap, cluster) 
    world = pants.World(nodes, euclidean) 
    solver = pants.Solver() 
    solution = solver.solve(world) 
    tour = [] 
    for coord in solution.tour: 
        tour.append(indexMap[coord])
    return tour 

optimalRoutes = []
indexMap = getIndexMap(data)
for cluster in clusters[top3clusters[0]]:
    if 0 in cluster:
        cluster.remove(0) 
    optimalRoutes.append(getOptimalRoute(indexMap, dataMap, cluster))

# %%
len(optimalRoutes)
# Out:
# 26

# %%
# evaluate the distances 

def getDistanceForRoute(route):
    totalDistance = 0 
    # deport to start 
    deportCoord = dataMap[0] 
    startCoord = dataMap[route[0]]
    totalDistance += getDistance(str(deportCoord[0]), str(deportCoord[1]), str(startCoord[0]), str(startCoord[1]))
    
    for i in range(0, (len(route)-1)): 
        coordA = dataMap[route[i]] 
        coordB = dataMap[route[(i+1)]] 
        
        totalDistance += getDistance(str(coordA[0]), str(coordA[1]), str(coordB[0]), str(coordB[1]))
   
    
    # end to deport 
    endCoord = dataMap[route[-1]] 
    totalDistance += getDistance(str(endCoord[0]), str(endCoord[1]), str(deportCoord[0]), str(deportCoord[1]))
    
    return totalDistance 

t = 0 
for opt in optimalRoutes:
    t += getDistanceForRoute(opt)
# Out:
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.89065,81.3454&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.89065,81.3454&destinations=8.8341,80.7607&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=8.8341,80.7607&destinations=9.6615,80.0255&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=9.6615,80.0255&destinations=8.1441,80.4119&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=8.1441,80.4119&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=7.08731,80.0144&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.08731,80.0144&destinations=7.24274,80.127&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24274,80.127&destinations=6.16557,80.9031&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.16557,80.9031&destinations=5.97168,80.6951&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.97168,80.6951&destinations=6.30653,80.6306&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.30653,80.6306&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=7.08731,80.0144&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.08731,80.0144&destinations=6.95179,79.9133&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.95179,79.9133&destinations=6.10014,80.476&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.10014,80.476&destinations=6.1226,81.0238&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.1226,81.0238&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.34249,80.5597&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.34249,80.5597&destinations=7.24274,80.127&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24274,80.127&destinations=7.29543,80.2366&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.29543,80.2366&destinations=6.15089,80.6937&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.15089,80.6937&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.27916,81.2877&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.27916,81.2877&destinations=7.22952,80.0151&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.22952,80.0151&destinations=7.24274,80.127&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24274,80.127&destinations=7.29057,80.6337&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.29057,80.6337&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.84328,80.0032&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.84328,80.0032&destinations=7.24813,80.4466&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24813,80.4466&destinations=7.24274,80.127&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24274,80.127&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.28804,80.1596&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.28804,80.1596&destinations=6.1688,80.1794&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.1688,80.1794&destinations=6.04816,80.7339&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.04816,80.7339&destinations=6.37318,80.3575&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.37318,80.3575&destinations=7.22952,80.0151&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.22952,80.0151&destinations=7.17229,79.8853&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.17229,79.8853&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.8018,79.9227&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.8018,79.9227&destinations=6.72023,79.9305&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.72023,79.9305&destinations=6.95179,79.9133&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.95179,79.9133&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=7.22952,80.0151&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.22952,80.0151&destinations=7.25133,80.3464&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.25133,80.3464&destinations=7.04587,80.2537&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.04587,80.2537&destinations=6.70558,80.3847&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.70558,80.3847&destinations=5.9774,80.4288&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.9774,80.4288&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.72297,80.0647&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.72297,80.0647&destinations=7.08731,80.0144&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.08731,80.0144&destinations=6.07792,80.5633&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.07792,80.5633&destinations=6.24416,80.0591&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.24416,80.0591&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.5854,79.9607&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.5854,79.9607&destinations=6.52195,80.1137&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.52195,80.1137&destinations=7.29419,80.7381&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.29419,80.7381&destinations=7.24274,80.127&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24274,80.127&destinations=6.95433,80.2046&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.95433,80.2046&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.95179,79.9133&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.95179,79.9133&destinations=6.90035,80.5966&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.90035,80.5966&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.66688,80.7048&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.66688,80.7048&destinations=6.31623,80.8433&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.31623,80.8433&destinations=7.17229,79.8853&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.17229,79.8853&destinations=7.17326,80.5605&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.17326,80.5605&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.82184,80.3615&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.82184,80.3615&destinations=7.24274,80.127&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24274,80.127&destinations=8.58737,81.2152&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=8.58737,81.2152&destinations=6.50491,80.6521&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.50491,80.6521&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.91218,79.8829&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.91218,79.8829&destinations=7.00251,79.9099&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.00251,79.9099&destinations=7.24274,80.127&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24274,80.127&destinations=7.04118,80.1289&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.04118,80.1289&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=7.24274,80.127&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24274,80.127&destinations=6.85222,79.9249&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.85222,79.9249&destinations=7.33161,81.0037&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.33161,81.0037&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=7.23176,81.6473&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.23176,81.6473&destinations=5.97398,80.3622&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.97398,80.3622&destinations=7.22952,80.0151&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.22952,80.0151&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=8.09828,80.0088&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=8.09828,80.0088&destinations=8.7542,80.4982&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=8.7542,80.4982&destinations=8.154,80.3046&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=8.154,80.3046&destinations=7.22952,80.0151&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.22952,80.0151&destinations=7.2008,79.8737&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.2008,79.8737&destinations=7.29746,79.8822&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.29746,79.8822&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=7.26987,80.5938&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.26987,80.5938&destinations=6.95179,79.9133&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.95179,79.9133&destinations=6.8216,80.0475&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.8216,80.0475&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.93491,81.1527&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.93491,81.1527&destinations=7.87422,80.6511&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.87422,80.6511&destinations=7.62391,80.2433&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.62391,80.2433&destinations=7.32954,80.0228&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.32954,80.0228&destinations=7.22952,80.0151&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.22952,80.0151&destinations=7.43216,80.4438&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.43216,80.4438&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.90191,80.9079&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.90191,80.9079&destinations=6.95179,79.9133&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.95179,79.9133&destinations=6.82588,80.9982&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.82588,80.9982&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=7.22952,80.0151&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.22952,80.0151&destinations=8.04159,80.9532&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=8.04159,80.9532&destinations=6.9934,81.055&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.9934,81.055&destinations=6.94622,79.9892&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.94622,79.9892&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=8.31135,80.4037&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=8.31135,80.4037&destinations=8.29214,80.7173&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=8.29214,80.7173&destinations=7.02888,80.2955&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.02888,80.2955&destinations=7.24274,80.127&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24274,80.127&destinations=7.56199,79.8017&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.56199,79.8017&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=7.94034,81.0188&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.94034,81.0188&destinations=7.47298,80.3547&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.47298,80.3547&destinations=7.08731,80.0144&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.08731,80.0144&destinations=6.73774,81.1031&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.73774,81.1031&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=6.93083,79.9842&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.93083,79.9842&destinations=7.10217,80.8627&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.10217,80.8627&destinations=7.46747,80.6234&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.46747,80.6234&destinations=7.91812,80.2405&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.91812,80.2405&destinations=7.24274,80.127&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.24274,80.127&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=5.95453,80.5492&destinations=7.08731,80.0144&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=7.08731,80.0144&destinations=6.927,79.864&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM
# https://maps.googleapis.com/maps/api/distancematrix/json?units=metric&origins=6.927,79.864&destinations=5.95453,80.5492&key=AIzaSyAV-a7YGrlk40IvZWCpLQg5yWnOkR3oCPM

# %%
t
# Out:
# 17866.708999999995

# %%
# solve using dynamic programming 
import numpy as np
from python_tsp.exact import solve_tsp_dynamic_programming


dataMap = createDataMap(data) 
def createDistanceMatrixForCluster(dataMap, cluster):
    points = [] 
    for c in cluster:
        longitude, latitude = float(dataMap[c][0]), float(dataMap[c][1]) 
        points.append([longitude,latitude]) 
    points = np.asarray(points) 
    return distance_matrix(points, points) 



optimalRoutes2 = []
indexMap = getIndexMap(data)
for cluster in clusters[top3clusters[0]]:
    if 0 in cluster:
        cluster.remove(0) 
    print(cluster)
    distance_matrix = createDistanceMatrixForCluster(dataMap, cluster) 
    permutation, distance = solve_tsp_dynamic_programming(distance_matrix)
    optimalRoutes2.append(permutation)
# Out:
# [81, 78, 66, 49]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-cc86b15d9fbf> in <module>
#      21         cluster.remove(0)
#      22     print(cluster)
# ---> 23     distance_matrix = createDistanceMatrixForCluster(dataMap, cluster)
#      24     permutation, distance = solve_tsp_dynamic_programming(distance_matrix)
#      25     optimalRoutes2.append(permutation)
#
# <ipython-input-26-cc86b15d9fbf> in createDistanceMatrixForCluster(dataMap, cluster)
#      11         points.append([longitude,latitude])
#      12     points = np.asarray(points)
# ---> 13     return distance_matrix(points, points)
#      14
#      15
#
# TypeError: 'numpy.ndarray' object is not callable
